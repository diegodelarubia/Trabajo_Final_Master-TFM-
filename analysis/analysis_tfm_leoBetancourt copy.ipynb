# %% [markdown]
# Importar las librerias necesarias

# %%
import pandas as pd
import numpy as np

from bs4 import BeautifulSoup
import fuzzywuzzy
import re

import os

# %%
bank_info = pd.read_csv('../../bank-additional_bank-additional-full.csv', sep= ';')
# bank-additional_bank-additional-full.csv
# /Users/betancle/1- Projects/Nuclio TFM/Trabajo_Final_Master-TFM-/bank-additional_bank-additional-full.csv

# %%
bank_info.sample(n = 10)
# Out:
#        age            job   marital            education  default housing  \
# 11757   42         admin.  divorced    university.degree       no     yes
# 2219    44    blue-collar   married          high.school  unknown     yes
# 7694    37  self-employed   married  professional.course  unknown     yes
# 39600   46     management   married             basic.9y       no     yes
# 22674   30         admin.    single    university.degree       no     yes
# 8613    42         admin.  divorced    university.degree       no      no
# 18152   28  self-employed   married    university.degree       no     yes
# 27715   61         admin.   married    university.degree       no     yes
# 14584   40         admin.  divorced          high.school       no     yes
# 31785   45     technician   married  professional.course       no      no
#
#       loan    contact month day_of_week  ...  campaign  pdays  previous  \
# 11757   no  telephone   jun         fri  ...         6    999         0
# 2219    no  telephone   may         mon  ...         3    999         0
# 7694    no  telephone   may         fri  ...        13    999         0
# 39600   no  telephone   may         wed  ...         1    999         0
# 22674   no   cellular   aug         fri  ...        10    999         0
# 8613    no  telephone   jun         wed  ...         1    999         0
# 18152  yes   cellular   jul         wed  ...         3    999         0
# 27715   no   cellular   mar         mon  ...         6    999         0
# 14584   no   cellular   jul         tue  ...         6    999         0
# 31785   no   cellular   may         thu  ...         1    999         0
#
#           poutcome emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 11757  nonexistent          1.4          94.465          -41.8      4.959
# 2219   nonexistent          1.1          93.994          -36.4      4.857
# 7694   nonexistent          1.1          93.994          -36.4      4.864
# 39600  nonexistent         -1.8          93.876          -40.0      0.672
# 22674  nonexistent          1.4          93.444          -36.1      4.964
# 8613   nonexistent          1.4          94.465          -41.8      4.864
# 18152  nonexistent          1.4          93.918          -42.7      4.963
# 27715  nonexistent         -1.8          92.843          -50.0      1.811
# 14584  nonexistent          1.4          93.918          -42.7      4.961
# 31785  nonexistent         -1.8          92.893          -46.2      1.327
#
#        nr.employed   y
# 11757       5228.1  no
# 2219        5191.0  no
# 7694        5191.0  no
# 39600       5008.7  no
# 22674       5228.1  no
# 8613        5228.1  no
# 18152       5228.1  no
# 27715       5099.1  no
# 14584       5228.1  no
# 31785       5099.1  no
#
# [10 rows x 21 columns]

# %%
bank_info.dtypes
# Out:
# age                 int64
# job                object
# marital            object
# education          object
# default            object
# housing            object
# loan               object
# contact            object
# month              object
# day_of_week        object
# duration            int64
# campaign            int64
# pdays               int64
# previous            int64
# poutcome           object
# emp.var.rate      float64
# cons.price.idx    float64
# cons.conf.idx     float64
# euribor3m         float64
# nr.employed       float64
# y                  object
# dtype: object

# %%
bank_info.describe().round(2)
# Out:
#             age  duration  campaign     pdays  previous  emp.var.rate  \
# count  41188.00  41188.00  41188.00  41188.00  41188.00      41188.00
# mean      40.02    258.29      2.57    962.48      0.17          0.08
# std       10.42    259.28      2.77    186.91      0.49          1.57
# min       17.00      0.00      1.00      0.00      0.00         -3.40
# 25%       32.00    102.00      1.00    999.00      0.00         -1.80
# 50%       38.00    180.00      2.00    999.00      0.00          1.10
# 75%       47.00    319.00      3.00    999.00      0.00          1.40
# max       98.00   4918.00     56.00    999.00      7.00          1.40
#
#        cons.price.idx  cons.conf.idx  euribor3m  nr.employed
# count        41188.00       41188.00   41188.00     41188.00
# mean            93.58         -40.50       3.62      5167.04
# std              0.58           4.63       1.73        72.25
# min             92.20         -50.80       0.63      4963.60
# 25%             93.08         -42.70       1.34      5099.10
# 50%             93.75         -41.80       4.86      5191.00
# 75%             93.99         -36.40       4.96      5228.10
# max             94.77         -26.90       5.04      5228.10

# %%
bank_info.isnull().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
bank_info[['pdays','previous']].value_counts()
# Out:
# pdays  previous
# 999    0           35563
#        1            3696
#        2             349
# 3      1             250
# 6      1             220
#                    ...
# 13     3               1
# 11     4               1
# 2      5               1
# 12     4               1
# 999    6               1
# Name: count, Length: 96, dtype: int64

# %%
bank_info.query('pdays != 999')['pdays'].describe().round(2)
# Out:
# count    1515.00
# mean        6.01
# std         3.82
# min         0.00
# 25%         3.00
# 50%         6.00
# 75%         7.00
# max        27.00
# Name: pdays, dtype: float64

# %%
bank_info['age'].value_counts()
# Out:
# age
# 31    1947
# 32    1846
# 33    1833
# 36    1780
# 35    1759
#       ...
# 89       2
# 91       2
# 94       1
# 87       1
# 95       1
# Name: count, Length: 78, dtype: int64

# %%
bank_info['education'].value_counts()
# Out:
# education
# university.degree      12168
# high.school             9515
# basic.9y                6045
# professional.course     5243
# basic.4y                4176
# basic.6y                2292
# unknown                 1731
# illiterate                18
# Name: count, dtype: int64
